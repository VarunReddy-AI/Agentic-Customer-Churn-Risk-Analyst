# %%
import pandas as pd

X = pd.read_csv("data/processed/X_train.csv")
print(X.columns.tolist())
# Out:
# ['tenure_months', 'monthly_charges', 'usage_minutes', 'support_calls', 'payment_delay_days', 'autopay', 'num_services', 'satisfaction_score', 'contract_type_one-year', 'contract_type_two-year', 'marketing_segment_B', 'marketing_segment_C', 'signup_channel_organic', 'signup_channel_partner', 'signup_channel_referral']

# %%
from src.utils.model_io import load_object
from src.config.config import SCALER_PATH

scaler = load_object(SCALER_PATH)

print(scaler.feature_names_in_)
# Out:
# ['tenure_months' 'monthly_charges' 'usage_minutes' 'payment_delay_days']

# %%
print(scaler.feature_names_in_)
# Out:
# ['tenure_months' 'monthly_charges' 'usage_minutes' 'payment_delay_days']

# %%
print(scaler.feature_names_in_)
# Out:
# ['tenure_months' 'monthly_charges' 'usage_minutes' 'payment_delay_days']

# %%
from src.utils.model_io import load_object
from src.config.config import SCALER_PATH

scaler = load_object(SCALER_PATH)

print(scaler.feature_names_in_)
# Out:
# ['tenure_months' 'monthly_charges' 'usage_minutes' 'support_calls'
#  'payment_delay_days' 'num_services' 'satisfaction_score']

# %%
from src.utils.model_io import load_object
from src.config.config import ENCODER_PATH

encoder = load_object(ENCODER_PATH)

print(encoder.feature_names_in_)
# Out:
# ['contract_type' 'marketing_segment' 'signup_channel']

# %%
from src.utils.model_io import load_object
from src.config.config import MODEL_PATH

model = load_object(MODEL_PATH)

print(model.feature_names_in_)
# Out:
# ['tenure_months' 'monthly_charges' 'usage_minutes' 'support_calls'
#  'payment_delay_days' 'autopay' 'num_services' 'satisfaction_score'
#  'contract_type_one-year' 'contract_type_two-year' 'marketing_segment_B'
#  'marketing_segment_C' 'signup_channel_organic' 'signup_channel_partner'
#  'signup_channel_referral']

# %%
import pandas as pd
from src.config.config import X_TRAIN_PATH

X_train = pd.read_csv(X_TRAIN_PATH)

print(X_train.columns.tolist())
# Out:
# ['tenure_months', 'monthly_charges', 'usage_minutes', 'support_calls', 'payment_delay_days', 'autopay', 'num_services', 'satisfaction_score', 'contract_type_one-year', 'contract_type_two-year', 'marketing_segment_B', 'marketing_segment_C', 'signup_channel_organic', 'signup_channel_partner', 'signup_channel_referral']

# %%
import pandas as pd
from src.config.config import RAW_DATA_PATH

df = pd.read_csv(RAW_DATA_PATH)

print(df.columns.tolist())
# Out:
# ['customer_id', 'tenure_months', 'monthly_charges', 'usage_minutes', 'support_calls', 'payment_delay_days', 'contract_type', 'autopay', 'num_services', 'satisfaction_score', 'signup_channel', 'marketing_segment', 'favorite_color', 'lucky_number', 'churn']
